# %% [markdown]
# ## Create_Schema_Bronze
#
# | Date         | Modified By      | Change Log             |
# |--------------|------------------|------------------------|
# | May 30th 2026| Sahithi Gudivada  | Creating the Table : jobs_raw |

# %%
spark.sql("""CREATE SCHEMA IF NOT EXISTS bronze""")
